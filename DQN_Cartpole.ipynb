# %%
import tensorflow as tf
import numpy as np
import collections
import gym
import random
import tensorflow.contrib.layers as layers

# %%
ENV = "CartPole-v0"

# %%
MEMORY_SIZE = 10000
EPISODES = 500
MAX_STEP = 500
BATCH_SIZE = 32
UPDATE_PERIOD = 200  # update target network parameters

# %%
##built class for the DQN
class DeepQNetwork():
    def __init__(self , env , sess=None , gamma = 0.8, epsilon = 0.8 ):
        self.gamma = gamma
        self.epsilon = epsilon
        self.action_dim = env.action_space.n
        self.state_dim = env.observation_space.shape[0]
        self.network()
        self.sess = sess
        self.sess.run(tf.global_variables_initializer())
        tf.summary.FileWriter("DQN/summaries" , sess.graph )
        
    # net_frame using for creating Q & target network
    def net_frame(self , hiddens, inpt, num_actions, scope, reuse=None):
        with tf.variable_scope(scope, reuse=reuse):
            out = inpt  
            for hidden in hiddens:
                out = layers.fully_connected(out,  num_outputs=hidden, activation_fn=tf.nn.relu)
            out = layers.fully_connected(out, num_outputs=num_actions, activation_fn=None) 
            return out
        
    # create q_network & target_network     
    def network(self):       
        # q_network
        self.inputs_q = tf.placeholder(dtype = tf.float32 , shape = [None , self.state_dim] , name = "inputs_q")
        scope_var = "q_network"    
        self.q_value = self.net_frame([64] , self.inputs_q , self.action_dim , scope_var , reuse = True )
            
        # target_network
        self.inputs_target = tf.placeholder(dtype = tf.float32 , shape = [None , self.state_dim] , name = "inputs_target")
        scope_tar = "target_network"    
        self.q_target = self.net_frame([64] , self.inputs_target , self.action_dim , scope_tar )
               
        with tf.variable_scope("loss"):
#            #【方案一】
#             self.target = tf.placeholder(dtype = tf.float32 , shape = [None , self.action_dim] , name = "target")
#             self.loss = tf.reduce_mean( tf.square(self.q_value - self.target))
            #【方案二】
            self.action = tf.placeholder(dtype = tf.int32 , shape = [ None ] , name = "action")
            action_one_hot = tf.one_hot(self.action , self.action_dim )
            q_action = tf.reduce_sum( tf.multiply(self.q_value , action_one_hot) , axis = 1 ) 
            
            self.target =  tf.placeholder(dtype = tf.float32 , shape =  [None ] , name = "target")
            self.loss = tf.reduce_mean( tf.square(q_action - self.target))

        with tf.variable_scope("train"):
            optimizer = tf.train.RMSPropOptimizer(0.001)
            self.train_op = optimizer.minimize(self.loss)    
    
    # training
    def train(self , state , reward , action , state_next , done):
        q , q_target = self.sess.run([self.q_value , self.q_target] , 
                                     feed_dict={self.inputs_q : state , self.inputs_target : state_next } )
#         #【方案一】
#         target = reward + self.gamma * np.max(q_target , axis = 1)*(1.0 - done)
        
#         self.reform_target = q.copy()
#         batch_index = np.arange(BATCH_SIZE , dtype = np.int32)
#         self.reform_target[batch_index , action] = target
            
#         loss , _ = self.sess.run([self.loss , self.train_op] , feed_dict={self.inputs_q: state , self.target: self.reform_target} )

        #【方案二】
        q_target_best = np.max(q_target , axis = 1)
        q_target_best_mask = ( 1.0 - done) * q_target_best
        
        target = reward + self.gamma * q_target_best_mask
        
        loss , _ = self.sess.run([self.loss , self.train_op] , 
                                 feed_dict={self.inputs_q: state , self.target:target , self.action:action} )    
    # chose action
    def chose_action(self , current_state):
        current_state = current_state[np.newaxis , :]  #*** array dim: (xx,)  --> (1 , xx) ***
        q = self.sess.run(self.q_value , feed_dict={self.inputs_q : current_state} )
        
        # e-greedy
        if np.random.random() < self.epsilon:
            action_chosen = np.random.randint(0 , self.action_dim)
        else:
            action_chosen = np.argmax(q)
        
        return action_chosen
         
    #upadate parmerters
    def update_prmt(self):
        q_prmts = tf.get_collection( tf.GraphKeys.GLOBAL_VARIABLES ,   "q_network"  )
        target_prmts = tf.get_collection( tf.GraphKeys.GLOBAL_VARIABLES,  "target_network"  )
        self.sess.run( [tf.assign(t , q)for t,q in zip(target_prmts , q_prmts)])  #***
        print("updating target-network parmeters...")
        
    def decay_epsilon(self):
        if self.epsilon > 0.03:
            self.epsilon = self.epsilon - 0.02

# %%
# memory for momery replay
memory = []
Transition = collections.namedtuple("Transition" , ["state", "action" , "reward" , "next_state" , "done"])

# %%
if __name__ == "__main__":
    env = gym.make(ENV)
    with tf.Session() as sess:
        DQN = DeepQNetwork(env , sess )
        update_iter = 0
        step_his = []
        for episode in range(EPISODES):
            state = env.reset()
            env.render() 
            reward_all = 0
            #training
            for step in range(MAX_STEP):
                action = DQN.chose_action(state)
                next_state , reward , done , _ = env.step(action)
                reward_all += reward 

                if len(memory) > MEMORY_SIZE:
                    memory.pop(0)
                memory.append(Transition(state, action , reward , next_state , float(done)))

                if len(memory) > BATCH_SIZE * 4:
                    batch_transition = random.sample(memory , BATCH_SIZE)
                    #***
                    batch_state, batch_action, batch_reward, batch_next_state, batch_done = map(np.array , zip(*batch_transition))  
                    DQN.train(state = batch_state ,
                              reward = batch_reward , 
                              action = batch_action , 
                              state_next = batch_next_state,
                              done = batch_done
                             )
                    update_iter += 1

                if update_iter % UPDATE_PERIOD == 0:
                    DQN.update_prmt()
                
                if update_iter % 200 == 0:
                    DQN.decay_epsilon()

                if done:
                    print("[episode = {} ] step = {}".format(episode , step))
                    break
                    
                state = next_state
# Out:
# [2017-06-16 10:32:02,009] Making new env: CartPole-v0
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# updating target-network parmeters...
# [episode = 0 ] step = 125
# updating target-network parmeters...
# updating target-network parmeters...
# [episode = 1 ] step = 24
# [episode = 2 ] step = 45
# [episode = 3 ] step = 51
# updating target-network parmeters...
# [episode = 4 ] step = 78
# [episode = 5 ] step = 58
# [episode = 6 ] step = 32
# [episode = 7 ] step = 28
# [episode = 8 ] step = 34
# [episode = 9 ] step = 11
# [episode = 10 ] step = 9
# [episode = 11 ] step = 8
# [episode = 12 ] step = 8
# updating target-network parmeters...
# [episode = 13 ] step = 8
# [episode = 14 ] step = 30
# [episode = 15 ] step = 45
# [episode = 16 ] step = 17
# [episode = 17 ] step = 8
# [episode = 18 ] step = 13
# [episode = 19 ] step = 9
# [episode = 20 ] step = 9
# [episode = 21 ] step = 10
# [episode = 22 ] step = 35
# updating target-network parmeters...
# [episode = 23 ] step = 11
# [episode = 24 ] step = 33
# [episode = 25 ] step = 39
# [episode = 26 ] step = 30
# [episode = 27 ] step = 22
# [episode = 28 ] step = 30
# [episode = 29 ] step = 19
# [episode = 30 ] step = 16
# updating target-network parmeters...
# [episode = 31 ] step = 38
# [episode = 32 ] step = 34
# [episode = 33 ] step = 49
# [episode = 34 ] step = 34
# [episode = 35 ] step = 18
# [episode = 36 ] step = 10
# updating target-network parmeters...
# [episode = 37 ] step = 20
# [episode = 38 ] step = 33
# [episode = 39 ] step = 62
# [episode = 40 ] step = 44
# [episode = 41 ] step = 26
# updating target-network parmeters...
# [episode = 42 ] step = 32
# [episode = 43 ] step = 10
# [episode = 44 ] step = 14
# [episode = 45 ] step = 45
# [episode = 46 ] step = 9
# [episode = 47 ] step = 9
# [episode = 48 ] step = 8
# [episode = 49 ] step = 9
# [episode = 50 ] step = 13
# [episode = 51 ] step = 9
# [episode = 52 ] step = 9
# [episode = 53 ] step = 8
# [episode = 54 ] step = 9
# [episode = 55 ] step = 9
# [episode = 56 ] step = 8
# updating target-network parmeters...
# [episode = 57 ] step = 11
# [episode = 58 ] step = 21
# [episode = 59 ] step = 35
# [episode = 60 ] step = 19
# [episode = 61 ] step = 11
# [episode = 62 ] step = 9
# [episode = 63 ] step = 22
# [episode = 64 ] step = 17
# [episode = 65 ] step = 9
# [episode = 66 ] step = 9
# [episode = 67 ] step = 11
# updating target-network parmeters...
# [episode = 68 ] step = 32
# [episode = 69 ] step = 14
# [episode = 70 ] step = 9
# [episode = 71 ] step = 11
# [episode = 72 ] step = 9
# [episode = 73 ] step = 17
# [episode = 74 ] step = 14
# [episode = 75 ] step = 22
# [episode = 76 ] step = 30
# [episode = 77 ] step = 8
# [episode = 78 ] step = 13
# [episode = 79 ] step = 10
# [episode = 80 ] step = 10
# updating target-network parmeters...
# [episode = 81 ] step = 9
# [episode = 82 ] step = 39
# [episode = 83 ] step = 30
# [episode = 84 ] step = 9
# [episode = 85 ] step = 33
# [episode = 86 ] step = 11
# [episode = 87 ] step = 9
# [episode = 88 ] step = 25
# [episode = 89 ] step = 10
# [episode = 90 ] step = 15
# updating target-network parmeters...
# [episode = 91 ] step = 21
# [episode = 92 ] step = 86
# [episode = 93 ] step = 19
# [episode = 94 ] step = 11
# [episode = 95 ] step = 9
# [episode = 96 ] step = 56
# updating target-network parmeters...
# [episode = 97 ] step = 9
# [episode = 98 ] step = 9
# [episode = 99 ] step = 10
# [episode = 100 ] step = 24
# [episode = 101 ] step = 20
# [episode = 102 ] step = 22
# [episode = 103 ] step = 36
# [episode = 104 ] step = 38
# updating target-network parmeters...
# [episode = 105 ] step = 34
# [episode = 106 ] step = 38
# [episode = 107 ] step = 92
# [episode = 108 ] step = 31
# updating target-network parmeters...
# [episode = 109 ] step = 60
# [episode = 110 ] step = 150
# updating target-network parmeters...
# [episode = 111 ] step = 68
# [episode = 112 ] step = 42
# [episode = 113 ] step = 22
# [episode = 114 ] step = 31
# [episode = 115 ] step = 31
# updating target-network parmeters...
# [episode = 116 ] step = 39
# [episode = 117 ] step = 44
# [episode = 118 ] step = 34
# [episode = 119 ] step = 29
# [episode = 120 ] step = 48
# updating target-network parmeters...
# [episode = 121 ] step = 44
# [episode = 122 ] step = 33
# [episode = 123 ] step = 19
# [episode = 124 ] step = 44
# [episode = 125 ] step = 56
# updating target-network parmeters...
# [episode = 126 ] step = 43
# [episode = 127 ] step = 36
# [episode = 128 ] step = 24
# [episode = 129 ] step = 33
# [episode = 130 ] step = 33
# updating target-network parmeters...
# [episode = 131 ] step = 52
# [episode = 132 ] step = 56
# [episode = 133 ] step = 59
# [episode = 134 ] step = 39
# updating target-network parmeters...
# [episode = 135 ] step = 48
# [episode = 136 ] step = 44
# [episode = 137 ] step = 39
# [episode = 138 ] step = 33
# updating target-network parmeters...
# [episode = 139 ] step = 135
# [episode = 140 ] step = 36
# [episode = 141 ] step = 38
# [episode = 142 ] step = 50
# updating target-network parmeters...
# [episode = 143 ] step = 44
# [episode = 144 ] step = 61
# [episode = 145 ] step = 48
# updating target-network parmeters...
# [episode = 146 ] step = 76
# [episode = 147 ] step = 106
# [episode = 148 ] step = 45
# updating target-network parmeters...
# [episode = 149 ] step = 74
# [episode = 150 ] step = 33
# [episode = 151 ] step = 61
# [episode = 152 ] step = 40
# updating target-network parmeters...
# [episode = 153 ] step = 62
# [episode = 154 ] step = 69
# [episode = 155 ] step = 42
# updating target-network parmeters...
# [episode = 156 ] step = 50
# [episode = 157 ] step = 58
# [episode = 158 ] step = 42
# [episode = 159 ] step = 65
# updating target-network parmeters...
# [episode = 160 ] step = 55
# [episode = 161 ] step = 41
# [episode = 162 ] step = 63
# updating target-network parmeters...
# [episode = 163 ] step = 57
# [episode = 164 ] step = 68
# [episode = 165 ] step = 48
# [episode = 166 ] step = 51
# updating target-network parmeters...
# [episode = 167 ] step = 80
# [episode = 168 ] step = 56
# [episode = 169 ] step = 49
# updating target-network parmeters...
# [episode = 170 ] step = 55
# [episode = 171 ] step = 73
# [episode = 172 ] step = 38
# [episode = 173 ] step = 56
# updating target-network parmeters...
# [episode = 174 ] step = 58
# [episode = 175 ] step = 94
# updating target-network parmeters...
# [episode = 176 ] step = 52
# [episode = 177 ] step = 46
# [episode = 178 ] step = 53
# [episode = 179 ] step = 67
# updating target-network parmeters...
# [episode = 180 ] step = 41
# [episode = 181 ] step = 79
# updating target-network parmeters...
# [episode = 182 ] step = 151
# [episode = 183 ] step = 51
# [episode = 184 ] step = 99
# updating target-network parmeters...
# [episode = 185 ] step = 48
# [episode = 186 ] step = 99
# updating target-network parmeters...
# [episode = 187 ] step = 69
# [episode = 188 ] step = 60
# updating target-network parmeters...
# [episode = 189 ] step = 172
# [episode = 190 ] step = 53
# [episode = 191 ] step = 56
# updating target-network parmeters...
# [episode = 192 ] step = 54
# [episode = 193 ] step = 93
# [episode = 194 ] step = 48
# updating target-network parmeters...
# [episode = 195 ] step = 89
# updating target-network parmeters...
# [episode = 196 ] step = 163
# [episode = 197 ] step = 106
# [episode = 198 ] step = 61
# updating target-network parmeters...
# [episode = 199 ] step = 61
# [episode = 200 ] step = 54
# [episode = 201 ] step = 67
# updating target-network parmeters...
# [episode = 202 ] step = 53
# [episode = 203 ] step = 80
# [episode = 204 ] step = 64
# updating target-network parmeters...
# [episode = 205 ] step = 68
# [episode = 206 ] step = 76
# [episode = 207 ] step = 66
# updating target-network parmeters...
# [episode = 208 ] step = 78
# [episode = 209 ] step = 59
# [episode = 210 ] step = 70
# updating target-network parmeters...
# [episode = 211 ] step = 68
# [episode = 212 ] step = 67
# updating target-network parmeters...
# [episode = 213 ] step = 73
# [episode = 214 ] step = 84
# [episode = 215 ] step = 62
# updating target-network parmeters...
# [episode = 216 ] step = 56
# [episode = 217 ] step = 98
# [episode = 218 ] step = 59
# updating target-network parmeters...
# [episode = 219 ] step = 66
# [episode = 220 ] step = 123
# updating target-network parmeters...
# [episode = 221 ] step = 184
# updating target-network parmeters...
# [episode = 222 ] step = 92
# [episode = 223 ] step = 96
# updating target-network parmeters...
# [episode = 224 ] step = 78
# [episode = 225 ] step = 165
# updating target-network parmeters...
# [episode = 226 ] step = 77
# [episode = 227 ] step = 63
# updating target-network parmeters...
# [episode = 228 ] step = 108
# [episode = 229 ] step = 63
# [episode = 230 ] step = 103
# updating target-network parmeters...
# [episode = 231 ] step = 155
# updating target-network parmeters...
# [episode = 232 ] step = 83
# [episode = 233 ] step = 88
# [episode = 234 ] step = 11
# updating target-network parmeters...
# [episode = 235 ] step = 106
# [episode = 236 ] step = 97
# updating target-network parmeters...
# [episode = 237 ] step = 95
# [episode = 238 ] step = 153
# updating target-network parmeters...
# [episode = 239 ] step = 107
# [episode = 240 ] step = 93
# updating target-network parmeters...
# [episode = 241 ] step = 96
# [episode = 242 ] step = 93
# updating target-network parmeters...
# [episode = 243 ] step = 72
# [episode = 244 ] step = 67
# updating target-network parmeters...
# [episode = 245 ] step = 89
# [episode = 246 ] step = 10
# [episode = 247 ] step = 12
# [episode = 248 ] step = 67
# [episode = 249 ] step = 76
# updating target-network parmeters...
# [episode = 250 ] step = 112
# updating target-network parmeters...
# [episode = 251 ] step = 107
# [episode = 252 ] step = 85
# [episode = 253 ] step = 73
# updating target-network parmeters...
# [episode = 254 ] step = 106
# updating target-network parmeters...
# [episode = 255 ] step = 199
# [episode = 256 ] step = 125
# updating target-network parmeters...
# [episode = 257 ] step = 64
# [episode = 258 ] step = 117
# updating target-network parmeters...
# [episode = 259 ] step = 93
# [episode = 260 ] step = 84
# [episode = 261 ] step = 10
# updating target-network parmeters...
# [episode = 262 ] step = 72
# [episode = 263 ] step = 79
# updating target-network parmeters...
# [episode = 264 ] step = 80
# [episode = 265 ] step = 70
# [episode = 266 ] step = 88
# updating target-network parmeters...
# [episode = 267 ] step = 112
# [episode = 268 ] step = 88
# updating target-network parmeters...
# [episode = 269 ] step = 80
# updating target-network parmeters...
# [episode = 270 ] step = 151
# [episode = 271 ] step = 161
# updating target-network parmeters...
# [episode = 272 ] step = 177
# updating target-network parmeters...
# [episode = 273 ] step = 179
# updating target-network parmeters...
# [episode = 274 ] step = 127
# [episode = 275 ] step = 121
# updating target-network parmeters...
# [episode = 276 ] step = 147
# updating target-network parmeters...
# [episode = 277 ] step = 138
# [episode = 278 ] step = 109
# updating target-network parmeters...
# [episode = 279 ] step = 145
# updating target-network parmeters...
# [episode = 280 ] step = 148
# [episode = 281 ] step = 119
# updating target-network parmeters...
# [episode = 282 ] step = 162
# updating target-network parmeters...
# [episode = 283 ] step = 129
# updating target-network parmeters...
# [episode = 284 ] step = 139
# [episode = 285 ] step = 116
# updating target-network parmeters...
# [episode = 286 ] step = 106
# [episode = 287 ] step = 74
# updating target-network parmeters...
# [episode = 288 ] step = 163
# [episode = 289 ] step = 113
# updating target-network parmeters...
# [episode = 290 ] step = 117
# updating target-network parmeters...
# [episode = 291 ] step = 117
# [episode = 292 ] step = 107
# updating target-network parmeters...
# [episode = 293 ] step = 91
# [episode = 294 ] step = 136
# updating target-network parmeters...
# [episode = 295 ] step = 134
# updating target-network parmeters...
# [episode = 296 ] step = 193
# updating target-network parmeters...
# [episode = 297 ] step = 146
# updating target-network parmeters...
# [episode = 298 ] step = 183
# updating target-network parmeters...
# [episode = 299 ] step = 197
# [episode = 300 ] step = 140
# updating target-network parmeters...
# [episode = 301 ] step = 113
# updating target-network parmeters...
# [episode = 302 ] step = 132
# [episode = 303 ] step = 174
# updating target-network parmeters...
# [episode = 304 ] step = 123
# updating target-network parmeters...
# [episode = 305 ] step = 196
# updating target-network parmeters...
# [episode = 306 ] step = 176
# updating target-network parmeters...
# [episode = 307 ] step = 188
# updating target-network parmeters...
# [episode = 308 ] step = 130
# [episode = 309 ] step = 185
# updating target-network parmeters...
# [episode = 310 ] step = 199
# updating target-network parmeters...
# [episode = 311 ] step = 199
# updating target-network parmeters...
# [episode = 312 ] step = 196
# updating target-network parmeters...
# [episode = 313 ] step = 199
# updating target-network parmeters...
# [episode = 314 ] step = 152
# updating target-network parmeters...
# [episode = 315 ] step = 199
# updating target-network parmeters...
# [episode = 316 ] step = 170
# updating target-network parmeters...
# [episode = 317 ] step = 144
# updating target-network parmeters...
# [episode = 318 ] step = 166
# updating target-network parmeters...
# [episode = 319 ] step = 184
# updating target-network parmeters...
# [episode = 320 ] step = 197
# [episode = 321 ] step = 147
# updating target-network parmeters...
# [episode = 322 ] step = 130
# updating target-network parmeters...
# [episode = 323 ] step = 133
# updating target-network parmeters...
# [episode = 324 ] step = 195
# [episode = 325 ] step = 169
# updating target-network parmeters...
# [episode = 326 ] step = 199
# updating target-network parmeters...
# [episode = 327 ] step = 199
# updating target-network parmeters...
# [episode = 328 ] step = 199
# updating target-network parmeters...
# [episode = 329 ] step = 199
# updating target-network parmeters...
# [episode = 330 ] step = 199
# updating target-network parmeters...
# [episode = 331 ] step = 158
# updating target-network parmeters...
# [episode = 332 ] step = 185
# updating target-network parmeters...
# [episode = 333 ] step = 175
# updating target-network parmeters...
# [episode = 334 ] step = 152
# updating target-network parmeters...
# [episode = 335 ] step = 168
# [episode = 336 ] step = 156
# updating target-network parmeters...
# [episode = 337 ] step = 170
# updating target-network parmeters...
# [episode = 338 ] step = 199
# updating target-network parmeters...
# [episode = 339 ] step = 199
# updating target-network parmeters...
# [episode = 340 ] step = 199
# updating target-network parmeters...
# [episode = 341 ] step = 199
# updating target-network parmeters...
# [episode = 342 ] step = 199
# updating target-network parmeters...
# [episode = 343 ] step = 62
# updating target-network parmeters...
# [episode = 344 ] step = 199
# updating target-network parmeters...
# [episode = 345 ] step = 187
# [episode = 346 ] step = 71
# updating target-network parmeters...
# [episode = 347 ] step = 153
# [episode = 348 ] step = 141
# updating target-network parmeters...
# [episode = 349 ] step = 152
# updating target-network parmeters...
# [episode = 350 ] step = 140
# updating target-network parmeters...
# [episode = 351 ] step = 193
# [episode = 352 ] step = 94
# updating target-network parmeters...
# [episode = 353 ] step = 125
# updating target-network parmeters...
# [episode = 354 ] step = 119
# [episode = 355 ] step = 60
# updating target-network parmeters...
# [episode = 356 ] step = 185
# [episode = 357 ] step = 127
# updating target-network parmeters...
# [episode = 358 ] step = 49
# updating target-network parmeters...
# [episode = 359 ] step = 199
# updating target-network parmeters...
# [episode = 360 ] step = 199
# [episode = 361 ] step = 61
# [episode = 362 ] step = 17
# [episode = 363 ] step = 23
# updating target-network parmeters...
# [episode = 364 ] step = 199
# updating target-network parmeters...
# [episode = 365 ] step = 107
# updating target-network parmeters...
# [episode = 366 ] step = 180
# [episode = 367 ] step = 21
# [episode = 368 ] step = 69
# updating target-network parmeters...
# [episode = 369 ] step = 153
# [episode = 370 ] step = 34
# [episode = 371 ] step = 34
# updating target-network parmeters...
# [episode = 372 ] step = 60
# [episode = 373 ] step = 111
# updating target-network parmeters...
# [episode = 374 ] step = 122
# [episode = 375 ] step = 23
# [episode = 376 ] step = 53
# updating target-network parmeters...
# [episode = 377 ] step = 107
# [episode = 378 ] step = 28
# [episode = 379 ] step = 22
# [episode = 380 ] step = 74
# [episode = 381 ] step = 20
# updating target-network parmeters...
# [episode = 382 ] step = 39
# [episode = 383 ] step = 121
# updating target-network parmeters...
# [episode = 384 ] step = 164
# [episode = 385 ] step = 76
# updating target-network parmeters...
# [episode = 386 ] step = 159
# updating target-network parmeters...
# [episode = 387 ] step = 134
# [episode = 388 ] step = 100
# updating target-network parmeters...
# [episode = 389 ] step = 118
# updating target-network parmeters...
# [episode = 390 ] step = 113
# [episode = 391 ] step = 143
# updating target-network parmeters...
# [episode = 392 ] step = 122
# updating target-network parmeters...
# [episode = 393 ] step = 130
# [episode = 394 ] step = 121
# updating target-network parmeters...
# [episode = 395 ] step = 122
# [episode = 396 ] step = 106
# updating target-network parmeters...
# [episode = 397 ] step = 114
# [episode = 398 ] step = 117
# updating target-network parmeters...
# [episode = 399 ] step = 104
# updating target-network parmeters...
# [episode = 400 ] step = 109
# [episode = 401 ] step = 119
# updating target-network parmeters...
# [episode = 402 ] step = 121
# [episode = 403 ] step = 108
# updating target-network parmeters...
# [episode = 404 ] step = 123
# updating target-network parmeters...
# [episode = 405 ] step = 166
# [episode = 406 ] step = 117
# updating target-network parmeters...
# [episode = 407 ] step = 132
# updating target-network parmeters...
# [episode = 408 ] step = 125
# [episode = 409 ] step = 110
# [episode = 410 ] step = 61
# updating target-network parmeters...
# [episode = 411 ] step = 101
# updating target-network parmeters...
# [episode = 412 ] step = 199
# updating target-network parmeters...
# [episode = 413 ] step = 199
# [episode = 414 ] step = 94
# updating target-network parmeters...
# [episode = 415 ] step = 155
# updating target-network parmeters...
# [episode = 416 ] step = 199
# updating target-network parmeters...
# [episode = 417 ] step = 199
# updating target-network parmeters...
# [episode = 418 ] step = 199
# updating target-network parmeters...
# [episode = 419 ] step = 199
# updating target-network parmeters...
# [episode = 420 ] step = 199
# updating target-network parmeters...
# [episode = 421 ] step = 163
# [episode = 422 ] step = 61
# updating target-network parmeters...
# [episode = 423 ] step = 154
# updating target-network parmeters...
# [episode = 424 ] step = 153
# updating target-network parmeters...
# [episode = 425 ] step = 199
# updating target-network parmeters...
# [episode = 426 ] step = 181
# updating target-network parmeters...
# [episode = 427 ] step = 150
# [episode = 428 ] step = 137
# updating target-network parmeters...
# [episode = 429 ] step = 134
# [episode = 430 ] step = 87
# updating target-network parmeters...
# [episode = 431 ] step = 102
# updating target-network parmeters...
# [episode = 432 ] step = 199
# [episode = 433 ] step = 73
# updating target-network parmeters...
# [episode = 434 ] step = 116
# [episode = 435 ] step = 79
# updating target-network parmeters...
# [episode = 436 ] step = 199
# updating target-network parmeters...
# [episode = 437 ] step = 199
# updating target-network parmeters...
# [episode = 438 ] step = 160
# updating target-network parmeters...
# [episode = 439 ] step = 143
# updating target-network parmeters...
# [episode = 440 ] step = 197
# [episode = 441 ] step = 35
# updating target-network parmeters...
# [episode = 442 ] step = 183
# updating target-network parmeters...
# [episode = 443 ] step = 199
# updating target-network parmeters...
# [episode = 444 ] step = 199
# updating target-network parmeters...
# [episode = 445 ] step = 199
# updating target-network parmeters...
# [episode = 446 ] step = 154
# updating target-network parmeters...
# [episode = 447 ] step = 199
# updating target-network parmeters...
# [episode = 448 ] step = 195
# updating target-network parmeters...
# [episode = 449 ] step = 199
# updating target-network parmeters...
# [episode = 450 ] step = 186
# [episode = 451 ] step = 188
# updating target-network parmeters...
# [episode = 452 ] step = 142
# updating target-network parmeters...
# [episode = 453 ] step = 199
# updating target-network parmeters...
# [episode = 454 ] step = 199
# updating target-network parmeters...
# [episode = 455 ] step = 186
# updating target-network parmeters...
# [episode = 456 ] step = 169
# updating target-network parmeters...
# [episode = 457 ] step = 190
# [episode = 458 ] step = 25
# updating target-network parmeters...
# [episode = 459 ] step = 90
# [episode = 460 ] step = 52
# [episode = 461 ] step = 36
# updating target-network parmeters...
# [episode = 462 ] step = 175
# updating target-network parmeters...
# [episode = 463 ] step = 170
# updating target-network parmeters...
# [episode = 464 ] step = 199
# updating target-network parmeters...
# [episode = 465 ] step = 199
# [episode = 466 ] step = 79
# updating target-network parmeters...
# [episode = 467 ] step = 199
# [episode = 468 ] step = 46
# [episode = 469 ] step = 15
# updating target-network parmeters...
# [episode = 470 ] step = 199
# updating target-network parmeters...
# [episode = 471 ] step = 50
# [episode = 472 ] step = 119
# updating target-network parmeters...
# [episode = 473 ] step = 199
# updating target-network parmeters...
# [episode = 474 ] step = 188
# updating target-network parmeters...
# [episode = 475 ] step = 199
# updating target-network parmeters...
# [episode = 476 ] step = 199
# updating target-network parmeters...
# [episode = 477 ] step = 71
# [episode = 478 ] step = 89
# [episode = 479 ] step = 66
# updating target-network parmeters...
# [episode = 480 ] step = 123
# updating target-network parmeters...
# [episode = 481 ] step = 170
# updating target-network parmeters...
# [episode = 482 ] step = 199
# updating target-network parmeters...
# [episode = 483 ] step = 198
# updating target-network parmeters...
# [episode = 484 ] step = 183
# updating target-network parmeters...
# [episode = 485 ] step = 146
# [episode = 486 ] step = 146
# updating target-network parmeters...
# [episode = 487 ] step = 199
# [episode = 488 ] step = 36
# updating target-network parmeters...
# [episode = 489 ] step = 68
# updating target-network parmeters...
# [episode = 490 ] step = 199
# [episode = 491 ] step = 84
# updating target-network parmeters...
# [episode = 492 ] step = 93
# [episode = 493 ] step = 126
# updating target-network parmeters...
# [episode = 494 ] step = 122
# updating target-network parmeters...
# [episode = 495 ] step = 199
# updating target-network parmeters...
# [episode = 496 ] step = 199
# updating target-network parmeters...
# [episode = 497 ] step = 165
# [episode = 498 ] step = 125
# updating target-network parmeters...
# [episode = 499 ] step = 170
